# %% [markdown]
# # Installing Spotipy

# %%
# conda install -c conda-forge spotipy

# %% [markdown]
# ## Loading credentials from the config file

# %% [markdown]
# #### Make sure that you have stored your spotify client_id and client_secret in a separate config.py file
# #### Once that's done, we import it

# %% [markdown]
# ## Starting with Spotify API

# %%
from dotenv import load_dotenv
import os
import spotipy
import pandas as pd
import json
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from spotipy import Spotify

load_dotenv()

#Initialize SpotiPy with user credentials
# Out:
# True

# %% [markdown]
# ### Step 1: Choose the Right Authentication Flow
#
# Spotify’s API has two main authentication flows:
#
# 1. Client Credentials Flow (SpotifyClientCredentials):
#     - Used for public data (e.g., song metadata, artist info).
#     - Does NOT require user login.
#     - Does not support user-specific actions (e.g., accessing saved tracks, playlists).
#     - Parameters: client_id, client_secret.
# 2. Authorization Code Flow (SpotifyOAuth):
#     - Used for user-specific data (e.g., saved tracks, playlists).
#     - Requires user login and permissions (scopes).
#     - Parameters: client_id, client_secret, redirect_uri, scope.
#
# <br> Either use     `SpotifyClientCredentials` or `SpotifyOAuth`
# Your code uses SpotifyClientCredentials, but you included redirect_uri and scope (which are only for SpotifyOAuth). This mismatch causes the error.

# %%
'''
# Initialize Spotify client SpotifyOAuth
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=os.getenv("SPOTIPY_CLIENT_ID"),
    client_secret=os.getenv("SPOTIPY_CLIENT_SECRET"),
    redirect_uri=os.getenv("SPOTIPY_REDIRECT_URI"),
    scope="user-library-read playlist-modify-private",  # Required permissions
    cache_path=".cache"  # Stores tokens locally (add to .gitignore)
))

# Initialize Spotify client with client credentials'''

# it doesn't work well
# Out:
# '\n# Initialize Spotify client SpotifyOAuth\nsp = spotipy.Spotify(auth_manager=SpotifyOAuth(\n    client_id=os.getenv("SPOTIPY_CLIENT_ID"),\n    client_secret=os.getenv("SPOTIPY_CLIENT_SECRET"),\n    redirect_uri=os.getenv("SPOTIPY_REDIRECT_URI"),\n    scope="user-library-read playlist-modify-private",  # Required permissions\n    cache_path=".cache"  # Stores tokens locally (add to .gitignore)\n))\n\n# Initialize Spotify client with client credentials'

# %%
# Initialize Spotify client SpotifyClientCredentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id=os.getenv("SPOTIPY_CLIENT_ID"),
    client_secret=os.getenv("SPOTIPY_CLIENT_SECRET")
))

# %% [markdown]
# # Understanding the json

# %% [markdown]
# ### Step 1: Search for an Artist
#
# To get an artist ID, search for the artist name and extract the ID from the results:
#
# the Json file contains the info of the artist also the ID
#
# #### Key Concepts to Remember
#
# 1. Search Syntax:
#     - q: Query string (use artist: or track: to filter).
#     - type: What to search for (artist, track, album).
#     - limit: Number of results to return.
# 2. Extracting IDs:
#     - IDs are always under the id key in the JSON response.
#     - For tracks: results['tracks']['items'][0]['id']
#     - For artists: results['artists']['items'][0]['id']
# 3. Using IDs:
#     - Once you have an ID, use methods like sp.artist() or sp.track() to get detailed info.

# %%
import pprint

# %%
# Search for an artist (e.g., Karol G)
artist_name = "Karol G"
results = sp.search(q='artist:' + artist_name, type='artist', limit=1)
display(results)
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=1&query=artist%3AKarol%20G&type=artist',
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?offset=1&limit=1&query=artist%3AKarol%20G&type=artist',
#   'offset': 0,
#   'previous': None,
#   'total': 100,
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#     'followers': {'href': None, 'total': 56293777},
#     'genres': ['reggaeton', 'latin', 'urbano latino'],
#     'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#     'id': '790FomKkXshlbRYZFtlgla',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb4b0754aefc9db490e02205ec',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab676161000051744b0754aefc9db490e02205ec',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f1784b0754aefc9db490e02205ec',
#       'height': 160,
#       'width': 160}],
#     'name': 'KAROL G',
#     'popularity': 89,
#     'type': 'artist',
#     'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}]}}

# %%
# pprint shows the results in a more readable format with more indentation
pprint.pprint(results)
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=1&query=artist%3AKarol%20G&type=artist',
#              'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#                         'followers': {'href': None, 'total': 56293777},
#                         'genres': ['reggaeton', 'latin', 'urbano latino'],
#                         'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#                         'id': '790FomKkXshlbRYZFtlgla',
#                         'images': [{'height': 640,
#                                     'url': 'https://i.scdn.co/image/ab6761610000e5eb4b0754aefc9db490e02205ec',
#                                     'width': 640},
#                                    {'height': 320,
#                                     'url': 'https://i.scdn.co/image/ab676161000051744b0754aefc9db490e02205ec',
#                                     'width': 320},
#                                    {'height': 160,
#                                     'url': 'https://i.scdn.co/image/ab6761610000f1784b0754aefc9db490e02205ec',
#                                     'width': 160}],
#                         'name': 'KAROL G',
#                         'popularity': 89,
#                         'type': 'artist',
#                         'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#              'limit': 1,
#              'next': 'https://api.spotify.com/v1/search?offset=1&limit=1&query=artist%3AKarol%20G&type=artist',
#              'offset': 0,
#              'previous': None,
#              'total': 100}}

# %%
# Extract the first artist's ID
artist = results['artists']['items'][0]
artist_id = artist['id']
print(f"Artist ID for {artist_name}: {artist_id}")
# Out:
# Artist ID for Karol G: 790FomKkXshlbRYZFtlgla

# %% [markdown]
# ### With JSON Dumps you can specify the indentation

# %%
results = sp.search(q='artist:Taylor Swift', type='artist', limit=1)
print(json.dumps(results, indent=4))
# Out:
# {
#     "artists": {
#         "href": "https://api.spotify.com/v1/search?offset=0&limit=1&query=artist%3ATaylor%20Swift&type=artist",
#         "limit": 1,
#         "next": "https://api.spotify.com/v1/search?offset=1&limit=1&query=artist%3ATaylor%20Swift&type=artist",
#         "offset": 0,
#         "previous": null,
#         "total": 10,
#         "items": [
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 136322473
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02",
#                 "id": "06HL4z0CvFAxyc27GXpf02",
#                 "images": [
#                     {
#                         "url": "https://i.scdn.co/image/ab6761610000e5ebe672b5f553298dcdccb0e676",
#                         "height": 640,
#                         "width": 640
#                     },
#                     {
#                         "url": "https://i.scdn.co/image/ab67616100005174e672b5f553298dcdccb0e676",
#                         "height": 320,
#                         "width": 320
#                     },
#                     {
#                         "url": "https://i.scdn.co/image/ab6761610000f178e672b5f553298dcdccb0e676",
#                         "height": 160,
#                         "width": 160
#                     }
#                 ],
#                 "name": "Taylor Swift",
#                 "popularity": 98,
#                 "type": "artist",
#                 "uri": "spotify:artist:06HL4z0CvFAxyc27GXpf02"
#             }
#         ]
#     }
# }

# %% [markdown]
# ## Getting the track_id
# using f-Strings
#
# If your query has multiple variables, f-strings shine:

# %%
# Search for a song (e.g., "Cruel Summer" by Taylor Swift)
track_name = "Cruel Summer"
artist_name = "Taylor Swift"

results_ts = sp.search(
    q=f'artist:{artist_name} track:{track_name}', 
    type='track', 
    limit=1
)

# Extract the first track's ID
track = results_ts['tracks']['items'][0]
track_id = track['id']
print(f"Track ID for {track_name}: {track_id}")

# pprint.pprint(results)
# Out:
# Track ID for Cruel Summer: 1BxfuPKGuaTgP7aM0Bbdwr

# %% [markdown]
# For the Band 'Tropikal Ravers'
# 1. get the artist

# %%
artist_name = "Tropikal Ravers"
results = sp.search(q=f'artist:{artist_name}', type='artist')
pprint.pprint(results)

# Extract the first artist's ID
artist = results['artists']['items'][0]
artist_id = artist['id']
print(f"Artist ID for {artist_name}: {artist_id}")
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=10&query=artist%3ATropikal%20Ravers&type=artist',
#              'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oFv4eL4BaId2on5ZaJDf4'},
#                         'followers': {'href': None, 'total': 32},
#                         'genres': [],
#                         'href': 'https://api.spotify.com/v1/artists/4oFv4eL4BaId2on5ZaJDf4',
#                         'id': '4oFv4eL4BaId2on5ZaJDf4',
#                         'images': [{'height': 640,
#                                     'url': 'https://i.scdn.co/image/ab67616d0000b273771ef83608cb40d47ec14181',
#                                     'width': 640},
#                                    {'height': 300,
#                                     'url': 'https://i.scdn.co/image/ab67616d00001e02771ef83608cb40d47ec14181',
#                                     'width': 300},
#                                    {'height': 64,
#                                     'url': 'https://i.scdn.co/image/ab67616d00004851771ef83608cb40d47ec14181',
#                                     'width': 64}],
#                         'name': 'Tropikal Ravers',
#                         'popularity': 0,
#                         'type': 'artist',
#                         'uri': 'spotify:artist:4oFv4eL4BaId2on5ZaJDf4'}],
#              'limit': 10,
#              'next': None,
#              'offset': 0,
#              'previous': None,
#              'total': 1}}
# Artist ID for Tropikal Ravers: 4oFv4eL4BaId2on5ZaJDf4

# %% [markdown]
# 2. get the tracks

# %%
artist_name = "Tropikal Ravers"
results = sp.search(q=f'artist:{artist_name}', type='track')
pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=10&query=artist%3ATropikal%20Ravers&type=track',
#             'items': [{'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oFv4eL4BaId2on5ZaJDf4'},
#                                               'href': 'https://api.spotify.com/v1/artists/4oFv4eL4BaId2on5ZaJDf4',
#                                               'id': '4oFv4eL4BaId2on5ZaJDf4',
#                                               'name': 'Tropikal Ravers',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:4oFv4eL4BaId2on5ZaJDf4'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/6yEt4DHEhqkOXVoBdBfCaW'},
#                                               'href': 'https://api.spotify.com/v1/artists/6yEt4DHEhqkOXVoBdBfCaW',
#                                               'id': '6yEt4DHEhqkOXVoBdBfCaW',
#                                               'name': 'Guillermo Fiallo '
#                                                       'Montero',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6yEt4DHEhqkOXVoBdBfCaW'}],
#                                  'available_markets': ['AR',
#                                                        'AU',
#                                                        'AT',
#                                                        'BE',
#                                                        'BO',
#                                                        'BR',
#                                                        'BG',
#                                                        'CA',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DK',
#                                                        'DO',
#                                                        'DE',
#                                                        'EC',
#                                                        'EE',
#                                                        'SV',
#                                                        'FI',
#                                                        'FR',
#                                                        'GR',
#                                                        'GT',
#                                                        'HN',
#                                                        'HK',
#                                                        'HU',
#                                                        'IS',
#                                                        'IE',
#                                                        'IT',
#                                                        'LV',
#                                                        'LT',
#                                                        'LU',
#                                                        'MY',
#                                                        'MT',
#                                                        'MX',
#                                                        'NL',
#                                                        'NZ',
#                                                        'NI',
#                                                        'NO',
#                                                        'PA',
#                                                        'PY',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'SG',
#                                                        'SK',
#                                                        'ES',
#                                                        'SE',
#                                                        'CH',
#                                                        'TW',
#                                                        'TR',
#                                                        'UY',
#                                                        'US',
#                                                        'GB',
#                                                        'AD',
#                                                        'LI',
#                                                        'MC',
#                                                        'ID',
#                                                        'JP',
#                                                        'TH',
#                                                        'VN',
#                                                        'RO',
#                                                        'IL',
#                                                        'ZA',
#                                                        'SA',
#                                                        'AE',
#                                                        'BH',
#                                                        'QA',
#                                                        'OM',
#                                                        'KW',
#                                                        'EG',
#                                                        'MA',
#                                                        'DZ',
#                                                        'TN',
#                                                        'LB',
#                                                        'JO',
#                                                        'PS',
#                                                        'IN',
#                                                        'BY',
#                                                        'KZ',
#                                                        'MD',
#                                                        'UA',
#                                                        'AL',
#                                                        'BA',
#                                                        'HR',
#                                                        'ME',
#                                                        'MK',
#                                                        'RS',
#                                                        'SI',
#                                                        'KR',
#                                                        'BD',
#                                                        'PK',
#                                                        'LK',
#                                                        'GH',
#                                                        'KE',
#                                                        'NG',
#                                                        'TZ',
#                                                        'UG',
#                                                        'AG',
#                                                        'AM',
#                                                        'BS',
#                                                        'BB',
#                                                        'BZ',
#                                                        'BT',
#                                                        'BW',
#                                                        'BF',
#                                                        'CV',
#                                                        'CW',
#                                                        'DM',
#                                                        'FJ',
#                                                        'GM',
#                                                        'GE',
#                                                        'GD',
#                                                        'GW',
#                                                        'GY',
#                                                        'HT',
#                                                        'JM',
#                                                        'KI',
#                                                        'LS',
#                                                        'LR',
#                                                        'MW',
#                                                        'MV',
#                                                        'ML',
#                                                        'MH',
#                                                        'FM',
#                                                        'NA',
#                                                        'NR',
#                                                        'NE',
#                                                        'PW',
#                                                        'PG',
#                                                        'PR',
#                                                        'WS',
#                                                        'SM',
#                                                        'ST',
#                                                        'SN',
#                                                        'SC',
#                                                        'SL',
#                                                        'SB',
#                                                        'KN',
#                                                        'LC',
#                                                        'VC',
#                                                        'SR',
#                                                        'TL',
#                                                        'TO',
#                                                        'TT',
#                                                        'TV',
#                                                        'VU',
#                                                        'AZ',
#                                                        'BN',
#                                                        'BI',
#                                                        'KH',
#                                                        'CM',
#                                                        'TD',
#                                                        'KM',
#                                                        'GQ',
#                                                        'SZ',
#                                                        'GA',
#                                                        'GN',
#                                                        'KG',
#                                                        'LA',
#                                                        'MO',
#                                                        'MR',
#                                                        'MN',
#                                                        'NP',
#                                                        'RW',
#                                                        'TG',
#                                                        'UZ',
#                                                        'ZW',
#                                                        'BJ',
#                                                        'MG',
#                                                        'MU',
#                                                        'MZ',
#                                                        'AO',
#                                                        'CI',
#                                                        'DJ',
#                                                        'ZM',
#                                                        'CD',
#                                                        'CG',
#                                                        'IQ',
#                                                        'LY',
#                                                        'TJ',
#                                                        'VE',
#                                                        'ET',
#                                                        'XK'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2iMZNArT2VT0MU1YHknjIS'},
#                                  'href': 'https://api.spotify.com/v1/albums/2iMZNArT2VT0MU1YHknjIS',
#                                  'id': '2iMZNArT2VT0MU1YHknjIS',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273771ef83608cb40d47ec14181',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02771ef83608cb40d47ec14181',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851771ef83608cb40d47ec14181',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'We Are',
#                                  'release_date': '2016-04-18',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 5,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2iMZNArT2VT0MU1YHknjIS'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oFv4eL4BaId2on5ZaJDf4'},
#                                     'href': 'https://api.spotify.com/v1/artists/4oFv4eL4BaId2on5ZaJDf4',
#                                     'id': '4oFv4eL4BaId2on5ZaJDf4',
#                                     'name': 'Tropikal Ravers',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:4oFv4eL4BaId2on5ZaJDf4'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6yEt4DHEhqkOXVoBdBfCaW'},
#                                     'href': 'https://api.spotify.com/v1/artists/6yEt4DHEhqkOXVoBdBfCaW',
#                                     'id': '6yEt4DHEhqkOXVoBdBfCaW',
#                                     'name': 'Guillermo Fiallo Montero',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6yEt4DHEhqkOXVoBdBfCaW'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'BY',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'PR',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 271111,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'FR2X41609402'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/4DAPGhtd1hxNkHtj8CklWU'},
#                        'href': 'https://api.spotify.com/v1/tracks/4DAPGhtd1hxNkHtj8CklWU',
#                        'id': '4DAPGhtd1hxNkHtj8CklWU',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'We Are Tropikal Ravers - Guillermo Fiallo '
#                                'Montero Manija Version',
#                        'popularity': 0,
#                        'preview_url': None,
#                        'track_number': 4,
#                        'type': 'track',
#                        'uri': 'spotify:track:4DAPGhtd1hxNkHtj8CklWU'},
#                       {'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oFv4eL4BaId2on5ZaJDf4'},
#                                               'href': 'https://api.spotify.com/v1/artists/4oFv4eL4BaId2on5ZaJDf4',
#                                               'id': '4oFv4eL4BaId2on5ZaJDf4',
#                                               'name': 'Tropikal Ravers',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:4oFv4eL4BaId2on5ZaJDf4'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/6yEt4DHEhqkOXVoBdBfCaW'},
#                                               'href': 'https://api.spotify.com/v1/artists/6yEt4DHEhqkOXVoBdBfCaW',
#                                               'id': '6yEt4DHEhqkOXVoBdBfCaW',
#                                               'name': 'Guillermo Fiallo '
#                                                       'Montero',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6yEt4DHEhqkOXVoBdBfCaW'}],
#                                  'available_markets': ['AR',
#                                                        'AU',
#                                                        'AT',
#                                                        'BE',
#                                                        'BO',
#                                                        'BR',
#                                                        'BG',
#                                                        'CA',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DK',
#                                                        'DO',
#                                                        'DE',
#                                                        'EC',
#                                                        'EE',
#                                                        'SV',
#                                                        'FI',
#                                                        'FR',
#                                                        'GR',
#                                                        'GT',
#                                                        'HN',
#                                                        'HK',
#                                                        'HU',
#                                                        'IS',
#                                                        'IE',
#                                                        'IT',
#                                                        'LV',
#                                                        'LT',
#                                                        'LU',
#                                                        'MY',
#                                                        'MT',
#                                                        'MX',
#                                                        'NL',
#                                                        'NZ',
#                                                        'NI',
#                                                        'NO',
#                                                        'PA',
#                                                        'PY',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'SG',
#                                                        'SK',
#                                                        'ES',
#                                                        'SE',
#                                                        'CH',
#                                                        'TW',
#                                                        'TR',
#                                                        'UY',
#                                                        'US',
#                                                        'GB',
#                                                        'AD',
#                                                        'LI',
#                                                        'MC',
#                                                        'ID',
#                                                        'JP',
#                                                        'TH',
#                                                        'VN',
#                                                        'RO',
#                                                        'IL',
#                                                        'ZA',
#                                                        'SA',
#                                                        'AE',
#                                                        'BH',
#                                                        'QA',
#                                                        'OM',
#                                                        'KW',
#                                                        'EG',
#                                                        'MA',
#                                                        'DZ',
#                                                        'TN',
#                                                        'LB',
#                                                        'JO',
#                                                        'PS',
#                                                        'IN',
#                                                        'BY',
#                                                        'KZ',
#                                                        'MD',
#                                                        'UA',
#                                                        'AL',
#                                                        'BA',
#                                                        'HR',
#                                                        'ME',
#                                                        'MK',
#                                                        'RS',
#                                                        'SI',
#                                                        'KR',
#                                                        'BD',
#                                                        'PK',
#                                                        'LK',
#                                                        'GH',
#                                                        'KE',
#                                                        'NG',
#                                                        'TZ',
#                                                        'UG',
#                                                        'AG',
#                                                        'AM',
#                                                        'BS',
#                                                        'BB',
#                                                        'BZ',
#                                                        'BT',
#                                                        'BW',
#                                                        'BF',
#                                                        'CV',
#                                                        'CW',
#                                                        'DM',
#                                                        'FJ',
#                                                        'GM',
#                                                        'GE',
#                                                        'GD',
#                                                        'GW',
#                                                        'GY',
#                                                        'HT',
#                                                        'JM',
#                                                        'KI',
#                                                        'LS',
#                                                        'LR',
#                                                        'MW',
#                                                        'MV',
#                                                        'ML',
#                                                        'MH',
#                                                        'FM',
#                                                        'NA',
#                                                        'NR',
#                                                        'NE',
#                                                        'PW',
#                                                        'PG',
#                                                        'PR',
#                                                        'WS',
#                                                        'SM',
#                                                        'ST',
#                                                        'SN',
#                                                        'SC',
#                                                        'SL',
#                                                        'SB',
#                                                        'KN',
#                                                        'LC',
#                                                        'VC',
#                                                        'SR',
#                                                        'TL',
#                                                        'TO',
#                                                        'TT',
#                                                        'TV',
#                                                        'VU',
#                                                        'AZ',
#                                                        'BN',
#                                                        'BI',
#                                                        'KH',
#                                                        'CM',
#                                                        'TD',
#                                                        'KM',
#                                                        'GQ',
#                                                        'SZ',
#                                                        'GA',
#                                                        'GN',
#                                                        'KG',
#                                                        'LA',
#                                                        'MO',
#                                                        'MR',
#                                                        'MN',
#                                                        'NP',
#                                                        'RW',
#                                                        'TG',
#                                                        'UZ',
#                                                        'ZW',
#                                                        'BJ',
#                                                        'MG',
#                                                        'MU',
#                                                        'MZ',
#                                                        'AO',
#                                                        'CI',
#                                                        'DJ',
#                                                        'ZM',
#                                                        'CD',
#                                                        'CG',
#                                                        'IQ',
#                                                        'LY',
#                                                        'TJ',
#                                                        'VE',
#                                                        'ET',
#                                                        'XK'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2iMZNArT2VT0MU1YHknjIS'},
#                                  'href': 'https://api.spotify.com/v1/albums/2iMZNArT2VT0MU1YHknjIS',
#                                  'id': '2iMZNArT2VT0MU1YHknjIS',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273771ef83608cb40d47ec14181',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02771ef83608cb40d47ec14181',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851771ef83608cb40d47ec14181',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'We Are',
#                                  'release_date': '2016-04-18',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 5,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2iMZNArT2VT0MU1YHknjIS'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oFv4eL4BaId2on5ZaJDf4'},
#                                     'href': 'https://api.spotify.com/v1/artists/4oFv4eL4BaId2on5ZaJDf4',
#                                     'id': '4oFv4eL4BaId2on5ZaJDf4',
#                                     'name': 'Tropikal Ravers',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:4oFv4eL4BaId2on5ZaJDf4'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'BY',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'PR',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
# ...
#                                                        'FM',
#                                                        'NA',
#                                                        'NR',
#                                                        'NE',
#                                                        'PW',
#                                                        'PG',
#                                                        'PR',
#                                                        'WS',
#                                                        'SM',
#                                                        'ST',
#                                                        'SN',
#                                                        'SC',
#                                                        'SL',
#                                                        'SB',
#                                                        'KN',
#                                                        'LC',
#                                                        'VC',
#                                                        'SR',
#                                                        'TL',
#                                                        'TO',
#                                                        'TT',
#                                                        'TV',
#                                                        'VU',
#                                                        'AZ',
#                                                        'BN',
#                                                        'BI',
#                                                        'KH',
#                                                        'CM',
#                                                        'TD',
#                                                        'KM',
#                                                        'GQ',
#                                                        'SZ',
#                                                        'GA',
#                                                        'GN',
#                                                        'KG',
#                                                        'LA',
#                                                        'MO',
#                                                        'MR',
#                                                        'MN',
#                                                        'NP',
#                                                        'RW',
#                                                        'TG',
#                                                        'UZ',
#                                                        'ZW',
#                                                        'BJ',
#                                                        'MG',
#                                                        'MU',
#                                                        'MZ',
#                                                        'AO',
#                                                        'CI',
#                                                        'DJ',
#                                                        'ZM',
#                                                        'CD',
#                                                        'CG',
#                                                        'IQ',
#                                                        'LY',
#                                                        'TJ',
#                                                        'VE',
#                                                        'ET',
#                                                        'XK'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2iMZNArT2VT0MU1YHknjIS'},
#                                  'href': 'https://api.spotify.com/v1/albums/2iMZNArT2VT0MU1YHknjIS',
#                                  'id': '2iMZNArT2VT0MU1YHknjIS',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273771ef83608cb40d47ec14181',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02771ef83608cb40d47ec14181',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851771ef83608cb40d47ec14181',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'We Are',
#                                  'release_date': '2016-04-18',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 5,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2iMZNArT2VT0MU1YHknjIS'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oFv4eL4BaId2on5ZaJDf4'},
#                                     'href': 'https://api.spotify.com/v1/artists/4oFv4eL4BaId2on5ZaJDf4',
#                                     'id': '4oFv4eL4BaId2on5ZaJDf4',
#                                     'name': 'Tropikal Ravers',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:4oFv4eL4BaId2on5ZaJDf4'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'BY',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'PR',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 311172,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'FR2X41609403'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/3hdEz3Ch43BwDAlXUIV4NA'},
#                        'href': 'https://api.spotify.com/v1/tracks/3hdEz3Ch43BwDAlXUIV4NA',
#                        'id': '3hdEz3Ch43BwDAlXUIV4NA',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Manija',
#                        'popularity': 0,
#                        'preview_url': None,
#                        'track_number': 5,
#                        'type': 'track',
#                        'uri': 'spotify:track:3hdEz3Ch43BwDAlXUIV4NA'}],
#             'limit': 10,
#             'next': None,
#             'offset': 0,
#             'previous': None,
#             'total': 5}}

# %%
artist_name = "Tropikal Ravers"
track_name = "We Are Tropikal Ravers"
results = sp.search(q=f'artist:{artist_name} track: {track_name}', type='track')
pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=10&query=artist%3ATropikal%20Ravers%20track%3A%20We%20Are%20Tropikal%20Ravers&type=track',
#             'items': [],
#             'limit': 10,
#             'next': None,
#             'offset': 0,
#             'previous': None,
#             'total': 0}}

# %% [markdown]
# ## Other Info

# %%
# Get artist details using the ID Artist ID for Tropikal Ravers: 4oFv4eL4BaId2on5ZaJDf4
tr_artist_id = '4oFv4eL4BaId2on5ZaJDf4'

artist_info = sp.artist(tr_artist_id)
print(f"Genres: {artist_info['genres']}")
print(f"Followers: {artist_info['followers']['total']}")
# Out:
# Genres: []
# Followers: 32

# %%
artist_name = "Kaleema"
results = sp.search(q=f'artist:{artist_name}', type='artist')
# pprint.pprint(results)

# Extract the first artist's ID
artist = results['artists']['items'][0]
artist_id = artist['id']
print(f"Artist ID for {artist_name}: {artist_id}")

artist_info = sp.artist(tr_artist_id)
print(f"Genres: {artist_info['genres']}")
print(f"Followers: {artist_info['followers']['total']}")
# Out:
# Artist ID for Kaleema: 7o5v2sjfFaMOgUKtfMQRWW
# Genres: []
# Followers: 32

# %%
# Get artist details using the ID Artist ID for Karol G: 790FomKkXshlbRYZFtlgla
artist_id = '790FomKkXshlbRYZFtlgla'

artist_info = sp.artist(artist_id)
print(f"Genres: {artist_info['genres']}")
print(f"Followers: {artist_info['followers']['total']}")
# Out:
# Genres: ['reggaeton', 'latin', 'urbano latino']
# Followers: 56293777

# %% [markdown]
# ## Embedded track player

# %%
from IPython.display import IFrame

# %%
track_name = "Blinding Lights"
artist_name = "The Weeknd"

results = sp.search(q=f'artist:{artist_name} track:{track_name}', type='track', limit=1)
track_id = results['tracks']['items'][0]['id']

# %%
from IPython.display import IFrame

# Generate the embed URL
embed_url = f"https://open.spotify.com/embed/track/{track_id}"

# Display the player
IFrame(src=embed_url, width="100%", height="380")
# Out:
#         <iframe
#             width="100%"
#             height="380"
#             src="https://open.spotify.com/embed/track/0VjIjW4GlUZAMYd2vXMi3b"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Getting the Audio features of a song

# %% [markdown]
# ## Building a Data frame of audio features

# %% [markdown]
# ## Searching a playlist

# %%
results = sp.search(q="2024 Top 50 - Argentina", type="playlist")
print(json.dumps(results, indent=2))  # View the full structure

# pprint.pprint(results)
# print(results)
# Out:
# {
#   "playlists": {
#     "href": "https://api.spotify.com/v1/search?offset=0&limit=10&query=2024%20Top%2050%20-%20Argentina&type=playlist",
#     "limit": 10,
#     "next": "https://api.spotify.com/v1/search?offset=10&limit=10&query=2024%20Top%2050%20-%20Argentina&type=playlist",
#     "offset": 0,
#     "previous": null,
#     "total": 804,
#     "items": [
#       {
#         "collaborative": false,
#         "description": "Top 50 Argentina , Los mejores temas del Reggaeton 2024 , El top 50 de Argentina 2024 , Argentina 2024 , top 50 Argentina, top Argentina, Reggaeton 2024 , contacto IG: Top50playlist",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/1q3yDrg9VG9eHmfk0j4eNa"
#         },
#         "href": "https://api.spotify.com/v1/playlists/1q3yDrg9VG9eHmfk0j4eNa",
#         "id": "1q3yDrg9VG9eHmfk0j4eNa",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da846bf221e89ead4ccb42cb58ec",
#             "width": null
#           }
#         ],
#         "name": "Top 50 Argentina 2024 \ud83c\udde6\ud83c\uddf7",
#         "owner": {
#           "display_name": "Top Playlists \ud83c\udfa7",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/12127843904"
#           },
#           "href": "https://api.spotify.com/v1/users/12127843904",
#           "id": "12127843904",
#           "type": "user",
#           "uri": "spotify:user:12127843904"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAAOPaIsbUr2I6SqDGR4JLMBoNyQamOo",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/1q3yDrg9VG9eHmfk0j4eNa/tracks",
#           "total": 66
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:1q3yDrg9VG9eHmfk0j4eNa"
#       },
#       null,
#       {
#         "collaborative": false,
#         "description": "Los mejores \u00e9xitos de Argentina 2024 -los 50 mejores argentinos",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/3xGZSKvGutOtLljSn60jPD"
#         },
#         "href": "https://api.spotify.com/v1/playlists/3xGZSKvGutOtLljSn60jPD",
#         "id": "3xGZSKvGutOtLljSn60jPD",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84129dbe27175ad00b8b99f176",
#             "width": null
#           }
#         ],
#         "name": "Argentina Top 50 | Hot hits Argentina  - Grandes \u00e9xitos argentinos 2024",
#         "owner": {
#           "display_name": "Viral Music ",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/bxgtbmu29zea5sjxq5q9jfzq5"
#           },
#           "href": "https://api.spotify.com/v1/users/bxgtbmu29zea5sjxq5q9jfzq5",
#           "id": "bxgtbmu29zea5sjxq5q9jfzq5",
#           "type": "user",
#           "uri": "spotify:user:bxgtbmu29zea5sjxq5q9jfzq5"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAAE5fnjZvvkgZp0T/0ya92pP3sI/dOK",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/3xGZSKvGutOtLljSn60jPD/tracks",
#           "total": 186
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:3xGZSKvGutOtLljSn60jPD"
#       },
#       {
#         "collaborative": false,
#         "description": "Entdecke die ultimative Playlist mit den hei\u00dfesten und neuesten Hits! Hier findest du alle Top-Songs aus dem Radio und den Charts, einschlie\u00dflich Nina Chuba, Apache207, Miley Cyrus, Harry Styles und vielen anderen.",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/1CnDCN10TJZjw6K2H3gNRv"
#         },
#         "href": "https://api.spotify.com/v1/playlists/1CnDCN10TJZjw6K2H3gNRv",
#         "id": "1CnDCN10TJZjw6K2H3gNRv",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000d72c90c887497a88a92828e96420",
#             "width": null
#           }
#         ],
#         "name": "Hits 2025 \ud83d\udd25 \ud83d\udd25  Aktuelle Charts und die besten Songs 2025 \ud83d\udd1d \ud83d\ude4c",
#         "owner": {
#           "display_name": "Filtr Germany",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/playlists.germany"
#           },
#           "href": "https://api.spotify.com/v1/users/playlists.germany",
#           "id": "playlists.germany",
#           "type": "user",
#           "uri": "spotify:user:playlists.germany"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAACo7joA1JUTJ32NjCgLfhri5fh++Sd",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/1CnDCN10TJZjw6K2H3gNRv/tracks",
#           "total": 132
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:1CnDCN10TJZjw6K2H3gNRv"
#       },
#       {
#         "collaborative": false,
#         "description": "Cumbia remix, Argentina 2023, LGANTE RKT, DJ ALAN GOMEZ, PAPUDJ, Ferpa, Bzrp Top 50 Argentina , Los mejores temas de Cumbia 2023, El top Cumbia, cachengue | Reggaeton remix, cumbia remix | cumbia remix 2023 callejero fino | La joaqui",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/16MXsD1FHEgfLdDjxA9rkV"
#         },
#         "href": "https://api.spotify.com/v1/playlists/16MXsD1FHEgfLdDjxA9rkV",
#         "id": "16MXsD1FHEgfLdDjxA9rkV",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84fb977740230fc860cd6b6b26",
#             "width": null
#           }
#         ],
#         "name": "Remix cumbia 2024 | Previa 2024 |  Argentina | Top 50",
#         "owner": {
#           "display_name": "Top Playlists \ud83c\udfa7",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/12127843904"
#           },
#           "href": "https://api.spotify.com/v1/users/12127843904",
#           "id": "12127843904",
#           "type": "user",
#           "uri": "spotify:user:12127843904"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAABeyqnAOjML0HFDh13cQixt9Jewc1j",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/16MXsD1FHEgfLdDjxA9rkV/tracks",
#           "total": 322
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:16MXsD1FHEgfLdDjxA9rkV"
#       },
#       null,
#       {
#         "collaborative": false,
#         "description": "Top Cumbia | Los mejores temas del  2024 | El top de Argentina, top 50 Argentina| top Argentina| Cumbia 2024 | cumbia Argentina, contacto IG: Top50playlist",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/1i2HHAJZiJSNUacdA7oF1u"
#         },
#         "href": "https://api.spotify.com/v1/playlists/1i2HHAJZiJSNUacdA7oF1u",
#         "id": "1i2HHAJZiJSNUacdA7oF1u",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84314d907ce222a2310efc8e08",
#             "width": null
#           }
#         ],
#         "name": "Cumbia Argentina \ud83c\udde6\ud83c\uddf72024",
#         "owner": {
#           "display_name": "Top Playlists \ud83c\udfa7",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/12127843904"
#           },
#           "href": "https://api.spotify.com/v1/users/12127843904",
#           "id": "12127843904",
#           "type": "user",
#           "uri": "spotify:user:12127843904"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAAFBYhdFxobSUTh+v4Mc9bJAlIJ1ibk",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/1i2HHAJZiJSNUacdA7oF1u/tracks",
#           "total": 69
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:1i2HHAJZiJSNUacdA7oF1u"
#       },
#       null,
#       {
#         "collaborative": false,
#         "description": "",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/70jYI3xf4i91Mu3EuCCh8J"
#         },
#         "href": "https://api.spotify.com/v1/playlists/70jYI3xf4i91Mu3EuCCh8J",
#         "id": "70jYI3xf4i91Mu3EuCCh8J",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://mosaic.scdn.co/640/ab67616d00001e02354487f00677506e68a40ee9ab67616d00001e0284c824e13c8dd1e9be71216aab67616d00001e02d5e4e308b658b1961130ccc0ab67616d00001e02d629a6041cde59d7ba67143c",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://mosaic.scdn.co/300/ab67616d00001e02354487f00677506e68a40ee9ab67616d00001e0284c824e13c8dd1e9be71216aab67616d00001e02d5e4e308b658b1961130ccc0ab67616d00001e02d629a6041cde59d7ba67143c",
#             "width": 300
#           },
#           {
#             "height": 60,
#             "url": "https://mosaic.scdn.co/60/ab67616d00001e02354487f00677506e68a40ee9ab67616d00001e0284c824e13c8dd1e9be71216aab67616d00001e02d5e4e308b658b1961130ccc0ab67616d00001e02d629a6041cde59d7ba67143c",
#             "width": 60
#           }
#         ],
#         "name": "Top 2025 \ud83c\udde6\ud83c\uddf7",
#         "owner": {
#           "display_name": "emibonanno10-ar",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/emibonanno10-ar"
#           },
#           "href": "https://api.spotify.com/v1/users/emibonanno10-ar",
#           "id": "emibonanno10-ar",
#           "type": "user",
#           "uri": "spotify:user:emibonanno10-ar"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAAd0g0pNI81tykvi87gkbvaNesG6eaN",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/70jYI3xf4i91Mu3EuCCh8J/tracks",
#           "total": 188
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:70jYI3xf4i91Mu3EuCCh8J"
#       },
#       null
#     ]
#   }
# }

# %%
from IPython.display import clear_output  # Optional: Clears previous output in notebooks

# Search for playlists by name
playlist_name = "2024 Top 50 - Argentina"
results = sp.search(q=playlist_name, type='playlist', limit=3)

# Print the first 5 matching playlists
print(f"Found {results['playlists']['total']} playlists matching '{playlist_name}':\n")

# pprint.pprint(results)

for idx, playlist in enumerate(results['playlists']['items']):
    print(f"{idx + 1}. {playlist['name']} (by {playlist['owner']['display_name']})")
    print(f"   Tracks: {playlist['tracks']['total']}")
    print(f"   ID: {playlist['id']}\n")
# Out:
# Found 804 playlists matching '2024 Top 50 - Argentina':
#
# 1. Top 50 Argentina 2024 🇦🇷 (by Top Playlists 🎧)
#    Tracks: 66
#    ID: 1q3yDrg9VG9eHmfk0j4eNa
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[141], line 13
#      10 # pprint.pprint(results)
#      12 for idx, playlist in enumerate(results['playlists']['items']):
# ---> 13     print(f"{idx + 1}. {playlist['name']} (by {playlist['owner']['display_name']})")
#      14     print(f"   Tracks: {playlist['tracks']['total']}")
#      15     print(f"   ID: {playlist['id']}\n")
#
# TypeError: 'NoneType' object is not subscriptable

# %%
playlists = sp.user_playlists('spotify')
while playlists:
    for i, playlist in enumerate(playlists['items']):
        print(f"{i + 1 + playlists['offset']:4d} {playlist['uri']} {playlist['name']}")
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None
# Out:
#    1 spotify:playlist:0NfjMqrzcGKVsbYZmhf4Md Classic Honky Tonk
#  224 spotify:playlist:0NKCe5F0ORuDO4sPmqhvcQ Moving Castle Monthly
#  225 spotify:playlist:4A01B3wh6uv7yOpzYdVLR3
#  226 spotify:playlist:4drXxn0GpOXXG6Rp5RvXca Bread & Dub
#  227 spotify:playlist:070FVPBKvfu6M5tf4I9rt2 The Blues Skies
#  228 spotify:playlist:5McngUiuALFIS4VVF4oko5 It Only Takes Two
#  229 spotify:playlist:2lOMjzyPMlcIvcaWlaF6MB Historic Venue: Ryman Auditorium
#  230 spotify:playlist:2JskSjr3Rl0LAv05L0hjV4 Vocal Acrobats
#  231 spotify:playlist:0TmNZR8QmL60k1gWWa37fg Macy's Thanksgiving Day Parade 2013
#  232 spotify:playlist:2d96NZvM6U7G14LDQdNfwS Austin Sounds
#  233 spotify:playlist:1MXbpQ8OiNsYtQxiXexPJ7 Sunset in Austin
#  234 spotify:playlist:6Sz7KT9MhChZuAJDKEWiLF Kanye To The
#  235 spotify:playlist:3sJ6SlgRo56Oa7YhHcLK5l Found Them First
#  236 spotify:playlist:2FjbiwWYHqEifO3VY5LYP8 New Year's 2015
#  237 spotify:playlist:3uDgik1xOhjYVsXucW7GEb A Bite Out Of The Afternoon
#  238 spotify:playlist:1Bxi8UJlVM7tLYDMOqsYYF Girls Night Out
#  239 spotify:playlist:7wiCMbRM2F6PQYGLwnJ7GJ Power Hour
#  240 spotify:playlist:3Nh594yQ7PkhEPzUUAKlnH Let Loose
#  241 spotify:playlist:3L1KIXcFcHhfeMlf7pD7IB Foam Party
#  242 spotify:playlist:6wz9sFJRqsmu7ldv0xJOIz An Epic Evening
#  243 spotify:playlist:08vPKM3pmoyF6crB2EtASQ Falling In Love
#  244 spotify:playlist:68oeNrImf1nxjL0RbpZkij Early Morning Rise
#  245 spotify:playlist:5qVqzAenJiKLfRny06XQf0 Backstage
#  246 spotify:playlist:1RKtKRcejWjN6ZOkghImIV Bullet for Hell
#  247 spotify:playlist:4C0S1zvtcMtk2notLxCL1J Grand Hustle Gang Spotify Picks
#  248 spotify:playlist:2nZndNnauO6SID8cjf4C9F MMG Spotify Picks
#  249 spotify:playlist:3hR94iGaotWbCFv5eDe0gZ Shady Records Spotify Picks
#  250 spotify:playlist:5VvCwhF9WqXKUaJLtJfeXn Taylor Gang Spotify Picks
#  251 spotify:playlist:6SGM9ZiMSfayAmJMNFlX2u country 90's
#  252 spotify:playlist:54LbSpjd64NjKPUyYAGkNU Hours of Ours
#  253 spotify:playlist:4p3lupatTubTWpTgCZjgpk Walk a Country Mile
#  254 spotify:playlist:6tLfPD2P9syvBV8rgO2Yq1 Honeysuckle Lazy
#  255 spotify:playlist:3FfBohQXFlgFnYubzrvoq4 On to Something Good
#  256 spotify:playlist:1S4JPQeJxtsN37X8as5EPk Back to the Roots
#  257 spotify:playlist:7CHrwiytyubNpnaZqyyUkb Beer 'n Burgers
#  258 spotify:playlist:4LmOnbOmtMUyQQjo6L9mct Bossa Nova
#  259 spotify:playlist:653U7cDBXXkPZ07Xk8kxL6 King of Pop
#  332 spotify:playlist:5eRHTcvWyEU0MEzNOiR2j1 Putte i parken 2012
#  333 spotify:playlist:4mM7tVGeVv4dOFPTlftofk Getaway Rock 2012
#  334 spotify:playlist:7DcfXNVB5WpzYwCkqBaVDx Peace & Love 2012
#  335 spotify:playlist:33eWAE7F4bBUAjGtJVtCYB Sveriges Nationaldag
#  336 spotify:playlist:3ukqAcaahACMyRzpkwHXew New year's eve by Icona Pop
#  337 spotify:playlist:5zyeLrOc31CPX7uk9xNL7y Swing in the New Year
#  338 spotify:playlist:214Nwj78JwTfjSeQxbGxeX Alternative New Year's Eve
#  339 spotify:playlist:3yUO32lGCEnAfFGORSEsy4 Raw Expression
#  340 spotify:playlist:2k9EArKbf7N3QUmuNJHSo8 Intervju med Seinabo Sey
#  341 spotify:playlist:5sk53m6HgZorO1RDUkaiIZ The official Bråvalla Festival playlist 2017
#  342 spotify:playlist:73boXMJz9iBoXxQVFZ94r5 International Playboy
#  343 spotify:playlist:2y74Ha0ztRUcIYmqITh0D4 National Blood Week
#  344 spotify:playlist:1k9jG0FUp7BcrAF1MZSabO Most Listened To British Dads on Spotify
#  345 spotify:playlist:5ji4GZJpll6twskFvKxiHx dw-c
#  346 spotify:playlist:40VxbK9NqccdUDUpiUXmbp dw_g
#  347 spotify:playlist:0RTz1jFo5BXGPfI8eVf8sj Top Shower Songs
#  348 spotify:playlist:4lgseztVwmKQ8MNETPVIny foodora dinner playlist

# %%
results = sp.search(q="2024 Top 100 Germany", type="playlist", limit=10, )

# print(json.dumps(results, indent=2, ensure_ascii=False)

# %%
# Example: Get the first non-null playlist in the results
playlist_id = None
for item in results['playlists']['items']:
    if item is not None:
        playlist_id = item['id']
        break  # Use the first valid playlist

print("Playlist ID:", '285lzweHjUYomX5888PvRa')  # Example: "285lzweHjUYomX5888PvRa"

playlist_tracks = sp.playlist_tracks('285lzweHjUYomX5888PvRa')

# Print tracks
for track in playlist_tracks['items']:
    song_name = track['track']['name']
    artist = track['track']['artists'][0]['name']
    print(f"{song_name} by {artist}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 3
#       1 # Example: Get the first non-null playlist in the results
#       2 playlist_id = None
# ----> 3 for item in results['playlists']['items']:
#       4     if item is not None:
#       5         playlist_id = item['id']
#
# KeyError: 'playlists'

# %%
results = sp.search(q="2024 Top 100 Germany", type="playlist", limit=10, )

print(json.dumps(results, indent=2, ensure_ascii=False))
# Out:
# {
#   "playlists": {
#     "href": "https://api.spotify.com/v1/search?offset=0&limit=10&query=2024%20Top%20100%20Germany&type=playlist",
#     "limit": 10,
#     "next": "https://api.spotify.com/v1/search?offset=10&limit=10&query=2024%20Top%20100%20Germany&type=playlist",
#     "offset": 0,
#     "previous": null,
#     "total": 805,
#     "items": [
#       {
#         "collaborative": false,
#         "description": "CHARTS APRIL 2025 APRIL TOP 100 SINGLE CHARTS DEUTSCHLAND SONGS GERMANY CHARTS GERMANY TOP 50 CHARTS RADIO SONGS RADIO LIEDER CHART TOPPERS  LATEST HITS  EDM APRIL 2025 NEW MUSIC FRIDAY AYLIVA DANCE POP HITS 2025 BILLBOARD CHARTS DJ SONGS 2025 TRENDING MUSIC 2025 ARBEIT MUSIK MUSIK ZUM ARBEIT",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/5CiverItIyXTNNfYLXC01c"
#         },
#         "href": "https://api.spotify.com/v1/playlists/5CiverItIyXTNNfYLXC01c",
#         "id": "5CiverItIyXTNNfYLXC01c",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84b0518a3199d1ee3d3b023605",
#             "width": null
#           }
#         ],
#         "name": "CHARTS APRIL  2025",
#         "owner": {
#           "display_name": "CHAPTER EIGHT",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/wtqcx4bhr0878brhugiqm5ms2"
#           },
#           "href": "https://api.spotify.com/v1/users/wtqcx4bhr0878brhugiqm5ms2",
#           "id": "wtqcx4bhr0878brhugiqm5ms2",
#           "type": "user",
#           "uri": "spotify:user:wtqcx4bhr0878brhugiqm5ms2"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAAFHwFz89GDCmDUi2h9MtEr0B4mtnZy",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/5CiverItIyXTNNfYLXC01c/tracks",
#           "total": 60
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:5CiverItIyXTNNfYLXC01c"
#       },
#       {
#         "collaborative": false,
#         "description": "Entdecke die ultimative Playlist mit den heißesten und neuesten Hits! Hier findest du alle Top-Songs aus dem Radio und den Charts, einschließlich Nina Chuba, Apache207, Miley Cyrus, Harry Styles und vielen anderen.",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/1CnDCN10TJZjw6K2H3gNRv"
#         },
#         "href": "https://api.spotify.com/v1/playlists/1CnDCN10TJZjw6K2H3gNRv",
#         "id": "1CnDCN10TJZjw6K2H3gNRv",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-fa.spotifycdn.com/image/ab67706c0000d72c90c887497a88a92828e96420",
#             "width": null
#           }
#         ],
#         "name": "Hits 2025 🔥 🔥  Aktuelle Charts und die besten Songs 2025 🔝 🙌",
#         "owner": {
#           "display_name": "Filtr Germany",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/playlists.germany"
#           },
#           "href": "https://api.spotify.com/v1/users/playlists.germany",
#           "id": "playlists.germany",
#           "type": "user",
#           "uri": "spotify:user:playlists.germany"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAACoSbYlfc2pbiraOobg1YxXtp3QHdt",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/1CnDCN10TJZjw6K2H3gNRv/tracks",
#           "total": 131
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:1CnDCN10TJZjw6K2H3gNRv"
#       },
#       {
#         "collaborative": false,
#         "description": "<a href=\"https://bit.ly/3YdC68w\">Hier klicken für alle Jahrescharts · </a>  Top 100 Jahrescharts Deutschland · Germany Single Charts Top 100 2004 · veröffentlicht am 06.12.2024 · Erfolgreichste Songs 2024 · Deutsche Charts früher",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/2ZSsc7fFT7J9GQbanZu29P"
#         },
#         "href": "https://api.spotify.com/v1/playlists/2ZSsc7fFT7J9GQbanZu29P",
#         "id": "2ZSsc7fFT7J9GQbanZu29P",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84dd1d894106964654880b45da",
#             "width": null
#           }
#         ],
#         "name": "Jahrescharts 2024 - Die Hits des Jahres · offizielle Top 100 Single-Charts 2024",
#         "owner": {
#           "display_name": "my.charts.music",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/teage03"
#           },
#           "href": "https://api.spotify.com/v1/users/teage03",
#           "id": "teage03",
#           "type": "user",
#           "uri": "spotify:user:teage03"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAABGRb2Mh9VIdqsReEsfJMOnfR82JqU",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/2ZSsc7fFT7J9GQbanZu29P/tracks",
#           "total": 100
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:2ZSsc7fFT7J9GQbanZu29P"
#       },
#       {
#         "collaborative": false,
#         "description": "Top 100 Germany Song Charts - Jeden Freitag aktuell. Wöchentliche, mengenbasierte Rangfolge der relevantesten Songs in Deutschland. Mehr auf mister-mixmania.com + News",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/46w2ClivIbhMgdqyGSKwvY"
#         },
#         "href": "https://api.spotify.com/v1/playlists/46w2ClivIbhMgdqyGSKwvY",
#         "id": "46w2ClivIbhMgdqyGSKwvY",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84426930c613ad06cee55fc64c",
#             "width": null
#           }
#         ],
#         "name": "Top 100 Germany Single - Song Charts vom 18.04.25",
#         "owner": {
#           "display_name": "Mister Mixmania",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/r26v0qtkcxs6q96mreuaa3mzs"
#           },
#           "href": "https://api.spotify.com/v1/users/r26v0qtkcxs6q96mreuaa3mzs",
#           "id": "r26v0qtkcxs6q96mreuaa3mzs",
#           "type": "user",
#           "uri": "spotify:user:r26v0qtkcxs6q96mreuaa3mzs"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAAEinT0Y1jwIjOUnbHQ0w6Bm9QfUvh5",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/46w2ClivIbhMgdqyGSKwvY/tracks",
#           "total": 100
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:46w2ClivIbhMgdqyGSKwvY"
#       },
#       {
#         "collaborative": false,
#         "description": "Radio Top 100 Germany - REL Top 40, FFH iTunes, Radio Harmony Top 40, Spotifý . Enjoy, DJ OKAY 14 - More Playlists from me: write &quot; DJ OKAY 14&quot; in search, and hit playlists on all ... Radio Top 40 , Party Dance Music , NDW - Neue Deutsche Welle , Summer Cocktail Party",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/2jn393YA9LPM9o5I4rzfqD"
#         },
#         "href": "https://api.spotify.com/v1/playlists/2jn393YA9LPM9o5I4rzfqD",
#         "id": "2jn393YA9LPM9o5I4rzfqD",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84b42d7678ed3302de5329fd58",
#             "width": null
#           }
#         ],
#         "name": "Radio Top  100 Germany 🎸 🎵  Airplay Charts 01.09.2024 REL, FFH iTunes, Harmony, Spotifý. DJ OKAY 14 ",
#         "owner": {
#           "display_name": "DJ OKAY 14",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/hvqquw1espbvye62jsalupef6"
#           },
#           "href": "https://api.spotify.com/v1/users/hvqquw1espbvye62jsalupef6",
#           "id": "hvqquw1espbvye62jsalupef6",
#           "type": "user",
#           "uri": "spotify:user:hvqquw1espbvye62jsalupef6"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAAWWJVmIxLfjFSk0L99jRLiiDXZVqWw",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/2jn393YA9LPM9o5I4rzfqD/tracks",
#           "total": 93
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:2jn393YA9LPM9o5I4rzfqD"
#       },
#       null,
#       {
#         "collaborative": false,
#         "description": "Song &#x2F; Single Charts - Das war 2024",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/48ovXYknwnw8ZLShQXgLOl"
#         },
#         "href": "https://api.spotify.com/v1/playlists/48ovXYknwnw8ZLShQXgLOl",
#         "id": "48ovXYknwnw8ZLShQXgLOl",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://mosaic.scdn.co/640/ab67616d00001e0249188fe723e4734b391f5162ab67616d00001e0272f356a0bf4ec66643e39516ab67616d00001e029a903819d8a5d3c80c47734cab67616d00001e02bef221ea02a821e7feeda9cf",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://mosaic.scdn.co/300/ab67616d00001e0249188fe723e4734b391f5162ab67616d00001e0272f356a0bf4ec66643e39516ab67616d00001e029a903819d8a5d3c80c47734cab67616d00001e02bef221ea02a821e7feeda9cf",
#             "width": 300
#           },
#           {
#             "height": 60,
#             "url": "https://mosaic.scdn.co/60/ab67616d00001e0249188fe723e4734b391f5162ab67616d00001e0272f356a0bf4ec66643e39516ab67616d00001e029a903819d8a5d3c80c47734cab67616d00001e02bef221ea02a821e7feeda9cf",
#             "width": 60
#           }
#         ],
#         "name": "Top 100 Germany Single Jahrescharts 2024",
#         "owner": {
#           "display_name": "Mister Mixmania",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/r26v0qtkcxs6q96mreuaa3mzs"
#           },
#           "href": "https://api.spotify.com/v1/users/r26v0qtkcxs6q96mreuaa3mzs",
#           "id": "r26v0qtkcxs6q96mreuaa3mzs",
#           "type": "user",
#           "uri": "spotify:user:r26v0qtkcxs6q96mreuaa3mzs"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAAABdbnFO8hJ3KPjZ0/SRPnIh5tI3tW",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/48ovXYknwnw8ZLShQXgLOl/tracks",
#           "total": 100
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:48ovXYknwnw8ZLShQXgLOl"
#       },
#       null,
#       {
#         "collaborative": false,
#         "description": "Top Charts Music for Germany 2024., Radio and Lists 🇩🇪 Charts, Top Hits, Deutchland, Pop Hits, Radio, Best Covers, Musik, Popular Music, Adam Port, Eminem, Sabrina Carpenter, Benson Bones, Billie Eilish",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/6cCsr8ICcaaKkeB5lCCYzO"
#         },
#         "href": "https://api.spotify.com/v1/playlists/6cCsr8ICcaaKkeB5lCCYzO",
#         "id": "6cCsr8ICcaaKkeB5lCCYzO",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84477a0584049642dbe551598b",
#             "width": null
#           }
#         ],
#         "name": "Charts Germany 2025 🇩🇪 Top Hits - Pop Hits - Top 100 Deutchland - Radio Songs ",
#         "owner": {
#           "display_name": "Hit Music Group",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/kpmvso2hddt008tdym03gycwi"
#           },
#           "href": "https://api.spotify.com/v1/users/kpmvso2hddt008tdym03gycwi",
#           "id": "kpmvso2hddt008tdym03gycwi",
#           "type": "user",
#           "uri": "spotify:user:kpmvso2hddt008tdym03gycwi"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AAAAFUjgJOQ6VQLnz4bbbDxLWBE9/izH",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/6cCsr8ICcaaKkeB5lCCYzO/tracks",
#           "total": 200
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:6cCsr8ICcaaKkeB5lCCYzO"
#       },
#       {
#         "collaborative": false,
#         "description": "",
#         "external_urls": {
#           "spotify": "https://open.spotify.com/playlist/0HFjjN19YWx5Snx38K5I2v"
#         },
#         "href": "https://api.spotify.com/v1/playlists/0HFjjN19YWx5Snx38K5I2v",
#         "id": "0HFjjN19YWx5Snx38K5I2v",
#         "images": [
#           {
#             "height": null,
#             "url": "https://image-cdn-ak.spotifycdn.com/image/ab67706c0000d72c232231b548f48dd5803f7972",
#             "width": null
#           }
#         ],
#         "name": "Top 100 Offizielle Deutsche Single-Charts vom 16.04.2025",
#         "owner": {
#           "display_name": "GfK Entertainment",
#           "external_urls": {
#             "spotify": "https://open.spotify.com/user/1130224284"
#           },
#           "href": "https://api.spotify.com/v1/users/1130224284",
#           "id": "1130224284",
#           "type": "user",
#           "uri": "spotify:user:1130224284"
#         },
#         "primary_color": null,
#         "public": true,
#         "snapshot_id": "AADuo2h1b4b1Wp7+YkXkAJUomXyHdet3",
#         "tracks": {
#           "href": "https://api.spotify.com/v1/playlists/0HFjjN19YWx5Snx38K5I2v/tracks",
#           "total": 100
#         },
#         "type": "playlist",
#         "uri": "spotify:playlist:0HFjjN19YWx5Snx38K5I2v"
#       }
#     ]
#   }
# }

# %%
'''
# Example usage
results = sp.current_user_saved_tracks(limit=5)
for idx, item in enumerate(results['items']):
    track = item['track']
    print(f"{idx + 1}. {track['name']} by {track['artists'][0]['name']}")
'''
# Out:
# '\n# Example usage\nresults = sp.current_user_saved_tracks(limit=5)\nfor idx, item in enumerate(results[\'items\']):\n    track = item[\'track\']\n    print(f"{idx + 1}. {track[\'name\']} by {track[\'artists\'][0][\'name\']}")\n'

# %% [markdown]
# ## Extracting a song from playlist

# %%
playlist_id = "1q3yDrg9VG9eHmfk0j4eNa"

# Get playlist metadata (name, owner, etc.)
playlist = sp.playlist(playlist_id)

# Get all tracks in the playlist (handle pagination)
def get_playlist_tracks(playlist_id):
    tracks = []
    offset = 0
    while True:
        response = sp.playlist_tracks(playlist_id, offset=offset)
        tracks.extend(response['items'])
        if not response['next']:
            break
        offset += 100
    return tracks

all_tracks = get_playlist_tracks(playlist_id)

# Print results
print(f"Playlist: {playlist['name']} (by {playlist['owner']['display_name']})")
print(f"Total tracks: {playlist['tracks']['total']}\n")

print("First 5 tracks:")
for idx, track in enumerate(all_tracks[:5]):
    track_name = track['track']['name']
    artist = track['track']['artists'][0]['name']
    print(f"{idx + 1}. {track_name} by {artist}")
# Out:
# Playlist: Top 50 Argentina 2024 🇦🇷 (by Top Playlists 🎧)
# Total tracks: 66
#
# First 5 tracks:
# 1. VITAMINA by Jombriel
# 2. Angelito by Bad Gyal
# 3. LOS DEPURO (feat. L-Gante) by Myke Towers
# 4. Luck Ra: Bzrp Music Sessions, Vol. 61 by Bizarrap
# 5. Olvidarte (feat. Emilia) by Gordo

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# Pagination using "next".
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
def get_all_playlist_tracks(playlist_id):
    tracks = []
    offset = 0
    
    while True:
        # Fetch tracks in batches of 100 (Spotify's max limit)
        response = sp.playlist_tracks(playlist_id, offset=offset, limit=100)
        tracks.extend(response['items'])
        
        # Exit loop if no more tracks
        if not response['next']:
            break
        
        offset += 100  # Move to the next page
    
    return tracks

# Example usage
playlist_id = "1q3yDrg9VG9eHmfk0j4eNa"  # Replace with your playlist ID
all_tracks = get_all_playlist_tracks(playlist_id)
print(f"Total tracks extracted: {len(all_tracks)}")
# Out:
# Total tracks extracted: 66

# %%
for track in all_tracks:
    if track['track']:  # Skip unavailable tracks (e.g., deleted songs)
        track_name = track['track']['name']
        artist_names = [artist['name'] for artist in track['track']['artists']]
        print(f"{track_name} by {', '.join(artist_names)}")
# Out:
# Bad Boy by Sayian Jimmy, Nysix Music, CamiMusic
# OA by Anuel AA, Quevedo, Maluma, Mambo Kingz, DJ Luian
# SI SABE FERXXO by Blessd, Feid
# GATITA GANGSTER by KAROL G, Dei V
# LA NENA by Lyanno, Rauw Alejandro
# offline by Young Miko, Feid
# Como Ninguna by JOA, Kainê
# POR QUÉ LLORAS? by Alan Gomez, Roze Oficial

# %% [markdown]
# ### Chopping a big playlist into chunks

# %%
CHUNK_SIZE = 20  # Adjust based on your needs

chunks = [
    all_tracks[i:i + CHUNK_SIZE] 
    for i in range(0, len(all_tracks), CHUNK_SIZE)
]

print(f"Split {len(all_tracks)} tracks into {len(chunks)} chunks")
# Out:
# Split 66 tracks into 4 chunks

# %%
for idx, chunk in enumerate(chunks):
    print(f"\nProcessing chunk {idx + 1} ({len(chunk)} tracks):")
    
    # Example: Save chunk to a CSV
    chunk_data = []
    for track in chunk:
        if track['track']:
            chunk_data.append({
                'name': track['track']['name'],
                'artist': track['track']['artists'][0]['name'],
                'id': track['track']['id']
            })
    
    # Convert to DataFrame and save
    df = pd.DataFrame(chunk_data)
    df.to_csv(f'playlist_chunk_{idx + 1}.csv', index=False)
    print(f"Saved chunk {idx + 1} to CSV")
# Out:
# Processing chunk 1 (20 tracks):
# Saved chunk 1 to CSV
#
# Processing chunk 2 (20 tracks):
# Saved chunk 2 to CSV
#
# Processing chunk 3 (20 tracks):
# Saved chunk 3 to CSV
#
# Processing chunk 4 (6 tracks):
# Saved chunk 4 to CSV

# %%
# Split into chunks
CHUNK_SIZE = 100
chunks = [all_tracks[i:i + CHUNK_SIZE] for i in range(0, len(all_tracks), CHUNK_SIZE)]

# Process each chunk
for idx, chunk in enumerate(chunks):
    print(f"Chunk {idx + 1} has {len(chunk)} tracks")
    # Add your custom logic here (e.g., analyze, save, etc.)
# Out:
# Chunk 1 has 66 tracks

# %% [markdown]
# ## Optional(Extra)

# %% [markdown]
# ## Getting the artists of the playlist

# %%
def get_playlist_artists(playlist_id):
    # Get all tracks from the playlist
    all_tracks = get_all_playlist_tracks(playlist_id)  # Use the pagination function from earlier
    
    # Collect unique artists
    artists = set()  # Sets automatically avoid duplicates
    
    for track in all_tracks:
        if track['track']:
            for artist in track['track']['artists']:
                artists.add(artist['name'])  # Add artist names to the set
    
    return list(artists)  # Convert to a list

# Example usage
playlist_id = "1q3yDrg9VG9eHmfk0j4eNa"  # Replace with your playlist ID
artists = get_playlist_artists(playlist_id)
print(f"Unique artists in the playlist: {len(artists)}")
print(artists[:50])  # Print first 10 artists
# Out:
# Unique artists in the playlist: 85
# ['Rauw Alejandro', 'Dímelo Flow', 'Blessd', 'Yandel', 'Peso Pluma', 'Nio Garcia', 'Lyanno', 'Justin Quiles', 'Luck Ra', 'LiL CaKe', 'MC Caverinha', 'Cris Mj', 'Anuel AA', 'Myke Towers', 'Dalex', 'Maria Becerra', 'Bizarrap', 'Dei V', 'The Academy: Segunda Misión', 'Trueno', 'Karamba', 'Young Miko', 'CamiMusic', 'Bhavi', 'Yexel', 'Gittobeatz', 'LZK Young', 'DJ Luian', 'Ozuna', 'Quevedo', 'Darell', 'Mambo Kingz', 'Neo Pistea', 'Jombriel', 'Anitta', 'Jay Wheeler', 'Kainê', 'Manuel Turizo', 'Duki', 'Emanero', 'Ivy Queen', 'Jere Klein', 'Lea in the Mix', 'Emilia', 'JOA', 'Lenny Tavárez', 'Jøtta', 'The La Planta', 'Ryan Castro', 'Mesita']

# %% [markdown]
# # Getting albums
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %% [markdown]
# Example: Coldplay

# %%
artist_name = "Coldplay"
results = sp.search(q=f'artist:{artist_name}', type='artist', limit=1)
artist_id = results['artists']['items'][0]['id']

# %%
def get_artist_albums(artist_id):
    albums = []
    offset = 0
    
    while True:
        # Fetch albums, singles, compilations
        response = sp.artist_albums(
            artist_id,
            album_type='album,single,compilation',
            limit=50,
            offset=offset
        )
        albums.extend(response['items'])
        
        if not response['next']:
            break
        offset += 50
    
    return albums

# Example usage
albums = get_artist_albums(artist_id)
print(f"Total albums/singles: {len(albums)}")

# Print album names and release years
for album in albums:
    print(f"{album['name']} ({album['release_date'][:4]})")
# Out:
# Total albums/singles: 121
# Moon Music (2024)
# Moon Music (Full Moon Edition) (2024)
# Music Of The Spheres (2021)
# Everyday Life (2019)
# Live in Buenos Aires (2018)
# A Head Full of Dreams (2015)
# Ghost Stories Live 2014 (2014)
# Ghost Stories (2014)
# Live 2012 (2012)
# Mylo Xyloto (2011)
# LeftRightLeftRightLeft (Live) (2009)
# Viva La Vida (Prospekt's March Edition) (2008)
# Viva La Vida or Death and All His Friends (2008)
# X&Y (2005)
# Live 2003 (2003)
# A Rush of Blood to the Head (2002)
# Parachutes (2000)
# WE PRAY (TWICE Version) (2025)
# Ma Meilleure Ennemie ft. Coldplay (2025)
# WE PRAY (Jasleen Royal Version) (2025)
# ALL MY LOVE (PNAU x Coldplay) (2024)
# ALL MY LOVE (2024)
# WE PRAY (Elyanna Version) (2024)
# WE PRAY (TINI Version) (2024)
# WE PRAY (2024)
# feelslikeimfallinginlove (Zerb x Coldplay) (2024)
# feelslikeimfallinginlove (2024)
# Biutyful (2022)
# Let Somebody Go (Ofenbach Remix) (2022)
# Let Somebody Go (Piano Version) (2022)
# Let Somebody Go (Kygo Remix) (2022)
# Let Somebody Go (2022)
# Spotify Singles (2022)
# My Universe (David Guetta Remix) (2021)
# My Universe (Galantis Remix) (2021)
# My Universe (2021)
# My Universe (SUGA's Remix) (2021)
# My Universe (2021)
# Coloratura (2021)
# Overtura (2021)
# Higher Power (Alyx Ander Remix) (2021)
# Higher Power (Acoustic Version) (2021)
# Higher Power (Tiësto Remix) (2021)
# Higher Power (ZHU Remix) (2021)
# Higher Power (2021)
# Flags (2020)
# Champion Of The World (Live at NPR's Tiny Desk) (2020)
# Champion of The World / Daddy (2019)
# Orphans (Muzi Remix) (2019)
# Everyday Life (2019)
# Orphans / Arabesque (2019)
# A Head Full of Dreams (Live in Buenos Aires) (2018)
# Fix You (Live in Buenos Aires) (2018)
# Viva La Vida (Live in Buenos Aires) (2018)
# A L I E N S (Markus Dravs Remix) (2017)
# Kaleidoscope EP (2017)
# A L I E N S (2017)
# Something Just Like This (Tokyo Remix) (2017)
# All I Can Think About Is You (2017)
# Something Just Like This (Remixes) (2017)
# Hypnotised (2017)
# Something Just Like This (2017)
# Live from Spotify London (2016)
# Everglow (2016)
# Up&Up (Freedo Remix) (2016)
# Up&Up (2016)
# Adventure of a Lifetime (Yotto Remix) (2016)
# Hymn for the Weekend (Seeb Remix) (2016)
# Adventure of a Lifetime (Matoma Remix) (2015)
# Everglow (2015)
# Adventure of a Lifetime (2015)
# True Love (Davide Rossi Remix) (2014)
# A Sky Full of Stars (Hardwell Remix) (2014)
# Ink (Live at Le Casino De Paris, Paris) (2014)
# True Love (2014)
# A Sky Full of Stars (Robin Schulz Remix) (2014)
# Wish I Was Here (2014)
# A Sky Full of Stars (2014)
# Midnight (Kygo Remix) (2014)
# Midnight (Remixes) (2014)
# A Sky Full of Stars (2014)
# Midnight (2014)
# Magic (2014)
# Atlas (From “The Hunger Games: Catching Fire” Soundtrack) (2013)
# Princess of China (Andre Sobota Remix) (2012)
# Princess of China (2012)
# Charlie Brown (2012)
# Charlie Brown (Dave Audé Remix) (2012)
# Hurts Like Heaven (2011)
# Paradise (2011)
# Every Teardrop Is a Waterfall (2011)
# Every Teardrop Is a Waterfall (2011)
# Christmas Lights (2010)
# Strawberry Swing (2009)
# Life in Technicolor ii (2009)
# Lost! (2008)
# Viva La Vida (2008)
# Prospekt's March (2008)
# Violet Hill (2008)
# The Hardest Part (2006)
# Talk (2005)
# Talk (2005)
# Fix You (2005)
# Fix You (2005)
# Speed of Sound (2005)
# Speed of Sound (2005)
# 2000 Miles (2003)
# Clocks (Royksopp Trembling Heart Mix) (2003)
# God Put a Smile upon Your Face (2003)
# Clocks (2003)
# Clocks (2003)
# Murder (2003)
# The Scientist (2002)
# In My Place (2002)
# Have Yourself a Merry Little Christmas (Jo Whiley, BBC Radio 1 Session) (2001)
# Don't Panic (2001)
# Trouble (2000)
# Yellow (2000)
# Shiver (2000)
# The Blue Room (1999)
# Brothers & Sisters (1999)

# %% [markdown]
# ## Getting the songs of a given album

# %%
album_name = "A Rush of Blood to the Head"
results = sp.search(q=f'album:{album_name} artist:Coldplay', type='album', limit=1)
album_id = results['albums']['items'][0]['id']

# %%
def get_album_tracks(album_id):
    tracks = []
    offset = 0
    
    while True:
        response = sp.album_tracks(album_id, offset=offset)
        tracks.extend(response['items'])
        
        if not response['next']:
            break
        offset += 100
    
    return tracks

# Example usage
tracks = get_album_tracks(album_id)
print(f"Tracks in '{album_name}':")
for idx, track in enumerate(tracks, 1):
    print(f"{idx}. {track['name']}")
# Out:
# Tracks in 'A Rush of Blood to the Head':
# 1. Politik
# 2. In My Place
# 3. God Put a Smile upon Your Face
# 4. The Scientist
# 5. Clocks
# 6. Daylight
# 7. Green Eyes
# 8. Warning Sign
# 9. A Whisper
# 10. A Rush of Blood to the Head
# 11. Amsterdam
